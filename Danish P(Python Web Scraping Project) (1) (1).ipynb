# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
Url = "https://www.spinny.com/blog/index.php/top-selling-car-brands-in-india/"

# %%
Page = requests.get(Url)
Page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(Page.text)
Soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <!-- Search Engine Optimization by Rank Math - https://s.rankmath.com/home -->
# <title>July 2023: Top Selling Car Brands in India | Spinny Car Magazine</title>
# <meta content="The Indian automotive industry continued to collect healthy sales figures yet another month. Here are the top selling car brands in India in May 2023." name="description"/>
# <meta content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/>
# <link href="https://www.spinny.com/blog/index.php/top-selling-car-brands-in-india/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# ...

# %%
table = Soup.find("table")
table = table.find("tbody")
table
# Out:
# <tbody><tr class="wptb-row"><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="0" data-y-index="0" style="padding: 15px; border-style: solid; border-width: 1px; border-color: rgb(219, 219, 219);"><div class="wptb-text-container wptb-ph-element wptb-element-text-1" style="color: rgb(74, 85, 104); font-size: 15px;"><div class="" style="position: relative;"><p style="text-align: center;"><strong>Car Brand</strong></p></div></div></td><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="1" data-y-index="0" style="padding: 15px; border-style: solid; border-width: 1px; border-color: rgb(219, 219, 219);"><div class="wptb-text-container wptb-ph-element wptb-element-text-2" style="color: rgb(74, 85, 104); font-size: 15px;"><div class="" style="position: relative;"><p style="text-align: center;"><strong>Units Sold in July 2023</strong></p></div></div></td><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="2" data-y-index="0" style="padd
# ...

# %%
rows = table.find_all("tr",style="")
rows
# Out:
# [<tr class="wptb-row"><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="0" data-y-index="0" style="padding: 15px; border-style: solid; border-width: 1px; border-color: rgb(219, 219, 219);"><div class="wptb-text-container wptb-ph-element wptb-element-text-1" style="color: rgb(74, 85, 104); font-size: 15px;"><div class="" style="position: relative;"><p style="text-align: center;"><strong>Car Brand</strong></p></div></div></td><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="1" data-y-index="0" style="padding: 15px; border-style: solid; border-width: 1px; border-color: rgb(219, 219, 219);"><div class="wptb-text-container wptb-ph-element wptb-element-text-2" style="color: rgb(74, 85, 104); font-size: 15px;"><div class="" style="position: relative;"><p style="text-align: center;"><strong>Units Sold in July 2023</strong></p></div></div></td><td class="wptb-cell" data-wptb-css-td-auto-width="true" data-x-index="2" data-y-index="0" style="padding: 1
# ...

# %%
Sales_info = []

for i in rows:
    columns = i.find_all("td")
    Car_Sales = [P.text for P in columns]
    Sales_info.append(Car_Sales)
print(Sales_info)
# Out:
# [['Car Brand', 'Units Sold in July 2023', 'Units Sold in July 2022', 'Y-O-Y Growth in Percentage'], ['Maruti Suzuki', '1,52,126', '1,42,850', '5.4%'], ['Hyundai', '50,701', '50,500', '0.4%'], ['Tata Motors', '47,630', '47,506', '0.3%'], ['Mahindra', '36,205', '27,771', '30.4%'], ['Toyota', '20,759', '19,693', '5.4%'], ['Kia', '20,002', '22,022', '-9.2%'], ['Morris Garages', '5,012', '4,013', '24.9%'], ['Honda', '4,864', '6,784', '-28.3%'], ['Skoda', '4,207', '4,447', '-5.4%'], ['Volkswagen', '3,814', '2,915', '31%']]

# %%
Car_Brand = []
Units_Sold_in_July_2023 = []
Units_Sold_in_July_2022 = []
Y_O_Y_Growth_in_Percentage = []

for i in Table_info:
    Car_Brand.append(i[0])
    Units_Sold_in_July_2023.append(i[1])
    Units_Sold_in_July_2022.append(i[2])
    Y_O_Y_Growth_in_Percentage.append(i[3])

# %%
Data = {"Car Brand" : Car_Brand, "Units Sold in July 2023" : Units_Sold_in_July_2023, "Units Sold in July 2022" : Units_Sold_in_July_2022, "Y-O-Y Growth in Percentage" : Y_O_Y_Growth_in_Percentage}

# %%
Car_Sales_info = pd.DataFrame(Data)
Car_Sales_info=Car_Sales_info.drop(0)
Car_Sales_info
# Out:
#          Car Brand Units Sold in July 2023 Units Sold in July 2022  \
# 1    Maruti Suzuki                1,52,126                1,42,850
# 2          Hyundai                  50,701                  50,500
# 3      Tata Motors                  47,630                  47,506
# 4         Mahindra                  36,205                  27,771
# 5           Toyota                  20,759                  19,693
# 6              Kia                  20,002                  22,022
# 7   Morris Garages                   5,012                   4,013
# 8            Honda                   4,864                   6,784
# 9            Skoda                   4,207                   4,447
# 10      Volkswagen                   3,814                   2,915
#
#    Y-O-Y Growth in Percentage
# 1                        5.4%
# 2                        0.4%
# 3                        0.3%
# 4                       30.4%
# 5                        5.4%
# 6                       -9.2%
# ...

# %%
Car_Sales_info.to_csv("Car Sales (India).csv")
